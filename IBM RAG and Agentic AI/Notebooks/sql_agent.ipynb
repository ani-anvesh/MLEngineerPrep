# %%
# Use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')
from langchain.agents import AgentType
from langchain_community.utilities.sql_database import SQLDatabase
from langchain_community.agent_toolkits import create_sql_agent

# %%
mysql_username = 'root'  # Replace with your server connect information
mysql_password = 'TGbWkWxf2iPljYE3mYm8ilBj' # Replace with your server connect information
mysql_host = '172.21.155.85' # Replace with your server connect information
mysql_port = '3306' # Replace with your server connect information
database_name = 'Chinook'
mysql_uri = f'mysql+mysqlconnector://{mysql_username}:{mysql_password}@{mysql_host}:{mysql_port}/{database_name}'
db = SQLDatabase.from_uri(mysql_uri)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/mysql/connector/connection_cext.py:354, in CMySQLConnection._open_connection(self)
#     353 try:
# --> 354     self._cmysql.connect(**cnx_kwargs)
#     355     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Can't connect to MySQL server on '172.21.155.85:3306' (60)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3297, in Engine.raw_connection(self)
#    3276 """Return a "raw" DBAPI connection from the connection pool.
#    3277
#    3278 The returned object is a proxied version of the DBAPI
#    (...)   3295
#    3296 """
# -> 3297 return self.pool.connect()
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
#     444 The connection is instrumented such that when its
#    (...)    447
#     448 """
# --> 449 return _ConnectionFairy._checkout(self)
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1263 if not fairy:
# -> 1264     fairy = _ConnectionRecord.checkout(pool)
#    1266     if threadconns is not None:
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:713, in _ConnectionRecord.checkout(cls, pool)
#     712 else:
# --> 713     rec = pool._do_get()
#     715 try:
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/pool/impl.py:179, in QueuePool._do_get(self)
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/util/langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/pool/impl.py:177, in QueuePool._do_get(self)
#     176 try:
# --> 177     return self._create_connection()
#     178 except:
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:390, in Pool._create_connection(self)
#     388 """Called by subclasses to create a new ConnectionRecord."""
# --> 390 return _ConnectionRecord(self)
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:675, in _ConnectionRecord.__init__(self, pool, connect)
#     674 if connect:
# --> 675     self.__connect()
#     676 self.finalize_callback = deque()
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:901, in _ConnectionRecord.__connect(self)
#     900 except BaseException as e:
# --> 901     with util.safe_reraise():
#     902         pool.logger.debug("Error on connect(): %s", e)
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/util/langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:897, in _ConnectionRecord.__connect(self)
#     896 self.starttime = time.time()
# --> 897 self.dbapi_connection = connection = pool._invoke_creator(self)
#     898 pool.logger.debug("Created new connection %r", connection)
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/engine/create.py:646, in create_engine.<locals>.connect(connection_record)
#     644             return connection
# --> 646 return dialect.connect(*cargs, **cparams)
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/engine/default.py:625, in DefaultDialect.connect(self, *cargs, **cparams)
#     623 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     624     # inherits the docstring from interfaces.Dialect.connect
# --> 625     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/mysql/connector/pooling.py:322, in connect(*args, **kwargs)
#     321 if CMySQLConnection and not use_pure:
# --> 322     return CMySQLConnection(*args, **kwargs)
#     323 return MySQLConnection(*args, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/mysql/connector/connection_cext.py:142, in CMySQLConnection.__init__(self, **kwargs)
#     141 try:
# --> 142     self.connect(**kwargs)
#     143 except Exception:
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/mysql/connector/abstracts.py:1604, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1603 self.disconnect()
# -> 1604 self._open_connection()
#    1606 charset, collation = (
#    1607     kwargs.pop("charset", None),
#    1608     kwargs.pop("collation", None),
#    1609 )
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/mysql/connector/connection_cext.py:360, in CMySQLConnection._open_connection(self)
#     359 if hasattr(err, "errno"):
# --> 360     raise get_mysql_exception(
#     361         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     362     ) from err
#     363 raise InterfaceError(str(err)) from err
#
# DatabaseError: 2003 (HY000): Can't connect to MySQL server on '172.21.155.85:3306' (60)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[2], line 7
#       5 database_name = 'Chinook'
#       6 mysql_uri = f'mysql+mysqlconnector://{mysql_username}:{mysql_password}@{mysql_host}:{mysql_port}/{database_name}'
# ----> 7 db = SQLDatabase.from_uri(mysql_uri)
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/langchain_community/utilities/sql_database.py:150, in SQLDatabase.from_uri(cls, database_uri, engine_args, **kwargs)
#     148 """Construct a SQLAlchemy engine from URI."""
#     149 _engine_args = engine_args or {}
# --> 150 return cls(create_engine(database_uri, **_engine_args), **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/langchain_community/utilities/sql_database.py:81, in SQLDatabase.__init__(self, engine, schema, metadata, ignore_tables, include_tables, sample_rows_in_table_info, indexes_in_table_info, custom_table_info, view_support, max_string_length, lazy_table_reflection)
#      78 if include_tables and ignore_tables:
#      79     raise ValueError("Cannot specify both include_tables and ignore_tables")
# ---> 81 self._inspector = inspect(self._engine)
#      83 # including view support by adding the views as well as tables to the all
#      84 # tables list if view_support is True
#      85 self._all_tables = set(
#      86     list(self._inspector.get_table_names(schema=schema))
#      87     + (self._inspector.get_view_names(schema=schema) if view_support else [])
#      88 )
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/inspection.py:140, in inspect(subject, raiseerr)
#     138 elif reg is True:
#     139     return subject
# --> 140 ret = reg(subject)
#     141 if ret is not None:
#     142     return ret
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/engine/reflection.py:313, in Inspector._engine_insp(bind)
#     311 @inspection._inspects(Engine)
#     312 def _engine_insp(bind: Engine) -> Inspector:  # type: ignore[misc]
# --> 313     return Inspector._construct(Inspector._init_engine, bind)
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/engine/reflection.py:246, in Inspector._construct(cls, init, bind)
#     243     cls = bind.dialect.inspector
#     245 self = cls.__new__(cls)
# --> 246 init(self, bind)
#     247 return self
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/engine/reflection.py:257, in Inspector._init_engine(self, engine)
#     255 def _init_engine(self, engine: Engine) -> None:
#     256     self.bind = self.engine = engine
# --> 257     engine.connect().close()
#     258     self._op_context_requires_connect = True
#     259     self.dialect = self.engine.dialect
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3273, in Engine.connect(self)
#    3250 def connect(self) -> Connection:
#    3251     """Return a new :class:`_engine.Connection` object.
#    3252
#    3253     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)   3270
#    3271     """
# -> 3273     return self._connection_cls(self)
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/engine/base.py:147, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
# --> 147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#     150         raise
#     151 else:
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2436, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2434 elif should_wrap:
#    2435     assert sqlalchemy_exception is not None
# -> 2436     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2437 else:
#    2438     assert exc_info[1] is not None
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 if connection is None:
#     144     try:
# --> 145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
#     147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3297, in Engine.raw_connection(self)
#    3275 def raw_connection(self) -> PoolProxiedConnection:
#    3276     """Return a "raw" DBAPI connection from the connection pool.
#    3277
#    3278     The returned object is a proxied version of the DBAPI
#    (...)   3295
#    3296     """
# -> 3297     return self.pool.connect()
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     441 def connect(self) -> PoolProxiedConnection:
#     442     """Return a DBAPI connection from the pool.
#     443
#     444     The connection is instrumented such that when its
#    (...)    447
#     448     """
# --> 449     return _ConnectionFairy._checkout(self)
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1256 @classmethod
#    1257 def _checkout(
#    1258     cls,
#    (...)   1261     fairy: Optional[_ConnectionFairy] = None,
#    1262 ) -> _ConnectionFairy:
#    1263     if not fairy:
# -> 1264         fairy = _ConnectionRecord.checkout(pool)
#    1266         if threadconns is not None:
#    1267             threadconns.current = weakref.ref(fairy)
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:713, in _ConnectionRecord.checkout(cls, pool)
#     711     rec = cast(_ConnectionRecord, pool._do_get())
#     712 else:
# --> 713     rec = pool._do_get()
#     715 try:
#     716     dbapi_connection = rec.get_connection()
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/pool/impl.py:179, in QueuePool._do_get(self)
#     177     return self._create_connection()
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#     181     raise
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/util/langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/pool/impl.py:177, in QueuePool._do_get(self)
#     175 if self._inc_overflow():
#     176     try:
# --> 177         return self._create_connection()
#     178     except:
#     179         with util.safe_reraise():
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:390, in Pool._create_connection(self)
#     387 def _create_connection(self) -> ConnectionPoolEntry:
#     388     """Called by subclasses to create a new ConnectionRecord."""
# --> 390     return _ConnectionRecord(self)
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:675, in _ConnectionRecord.__init__(self, pool, connect)
#     673 self.__pool = pool
#     674 if connect:
# --> 675     self.__connect()
#     676 self.finalize_callback = deque()
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:901, in _ConnectionRecord.__connect(self)
#     899     self.fresh = True
#     900 except BaseException as e:
# --> 901     with util.safe_reraise():
#     902         pool.logger.debug("Error on connect(): %s", e)
#     903 else:
#     904     # in SQLAlchemy 1.4 the first_connect event is not used by
#     905     # the engine, so this will usually not be set
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/util/langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:897, in _ConnectionRecord.__connect(self)
#     895 try:
#     896     self.starttime = time.time()
# --> 897     self.dbapi_connection = connection = pool._invoke_creator(self)
#     898     pool.logger.debug("Created new connection %r", connection)
#     899     self.fresh = True
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/engine/create.py:646, in create_engine.<locals>.connect(connection_record)
#     643         if connection is not None:
#     644             return connection
# --> 646 return dialect.connect(*cargs, **cparams)
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/sqlalchemy/engine/default.py:625, in DefaultDialect.connect(self, *cargs, **cparams)
#     623 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     624     # inherits the docstring from interfaces.Dialect.connect
# --> 625     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/mysql/connector/pooling.py:322, in connect(*args, **kwargs)
#     319         raise ImportError(ERROR_NO_CEXT)
#     321 if CMySQLConnection and not use_pure:
# --> 322     return CMySQLConnection(*args, **kwargs)
#     323 return MySQLConnection(*args, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/mysql/connector/connection_cext.py:142, in CMySQLConnection.__init__(self, **kwargs)
#     140 if kwargs:
#     141     try:
# --> 142         self.connect(**kwargs)
#     143     except Exception:
#     144         self.close()
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/mysql/connector/abstracts.py:1604, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1601     self.config(**kwargs)
#    1603 self.disconnect()
# -> 1604 self._open_connection()
#    1606 charset, collation = (
#    1607     kwargs.pop("charset", None),
#    1608     kwargs.pop("collation", None),
#    1609 )
#    1610 if charset or collation:
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlengineerprep-fSSVlCLJ-py3.11/lib/python3.11/site-packages/mysql/connector/connection_cext.py:360, in CMySQLConnection._open_connection(self)
#     358 except MySQLInterfaceError as err:
#     359     if hasattr(err, "errno"):
# --> 360         raise get_mysql_exception(
#     361             err.errno, msg=err.msg, sqlstate=err.sqlstate
#     362         ) from err
#     363     raise InterfaceError(str(err)) from err
#     365 self._do_handshake()
#
# DatabaseError: (mysql.connector.errors.DatabaseError) 2003 (HY000): Can't connect to MySQL server on '172.21.155.85:3306' (60)
# (Background on this error at: https://sqlalche.me/e/20/4xp6)

# %%
agent_executor = create_sql_agent(llm=llm, db=db, verbose=True, handle_parsing_errors=True, agent_type=AgentType.ZERO_SHOT_REACT_DESCRIPTION)
agent_executor.invoke(
    "How many Album are there in the database?"
)
